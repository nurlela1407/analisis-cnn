# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# ...
#   Using cached grpcio-1.43.0-cp39-cp39-win_amd64.whl (3.4 MB)
# ...
#      ---------------------------------------- 1.5/1.5 MB 39.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.8/2.8 MB 80.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.6/42.6 KB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 KB 1.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 126.7/126.7 KB 1.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# ...
#      -------------------------------------- 13.9/13.9 MB 746.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 462.5/462.5 KB 1.2 MB/s eta 0:00:00
# ...
#
# ...
#      ---------------------------------------- 5.8/5.8 MB 1.6 MB/s eta 0:00:00
# ...
